# %%
# !tar -xzvf llm_output.tar.gz
# Out:
# Database_full_dump.csv

# %%
import pandas as pd
llm_df = pd.read_csv("Database_full_dump.csv")

# %%
llm_df.head()
# Out:
#                         _id                           DOI  \
# 0  66cd90dceafcc23b8740dd29  10.1371/journal.pone.0238557
# 1  66cd93a1eafcc23b8740dd2a           10.1098/rsos.150088
# 2  66cd966aeafcc23b8740dd2b  10.1371/journal.pone.0041732
# 3  66cd98c6eafcc23b8740dd2c  10.1371/journal.pone.0022746
# 4  66cd9bf2eafcc23b8740dd2d        10.1098/rsbl.2008.0118
#
#                                                title  \
# 0  eDNA metabarcoding as a biomonitoring tool for...
# 1  MiFish, a set of universal PCR primers for met...
# 2  Detection of a Diverse Marine Fish Fauna Using...
# 3  Molecular Detection of Vertebrates in Stream W...
# 4  "Occupancy estimation and modeling: inferring ...
#
#                                              content  \
# 0  Monitoring of marine protected areas (MPAs) is...
# 1  We developed a set of universal PCR primers (M...
# 2  Marine ecosystems worldwide are under threat w...
# 3  Stream ecosystems harbor many secretive and im...
# ...

# %%
# !rm Database_full_dump.csv
