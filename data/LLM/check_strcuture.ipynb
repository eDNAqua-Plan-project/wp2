# %%
import pandas as pd
llm_dump = "/home/camilababo/Documents/eDNAqua-Plan/Database_full_dump.csv"

# %%
llm_df = pd.read_csv(llm_dump)

# %%
llm_df
# Out:
#                            _id                           DOI  \
# 0     66cd90dceafcc23b8740dd29  10.1371/journal.pone.0238557
# 1     66cd93a1eafcc23b8740dd2a           10.1098/rsos.150088
# 2     66cd966aeafcc23b8740dd2b  10.1371/journal.pone.0041732
# 3     66cd98c6eafcc23b8740dd2c  10.1371/journal.pone.0022746
# 4     66cd9bf2eafcc23b8740dd2d        10.1098/rsbl.2008.0118
# ...                        ...                           ...
# 1602  66f050482d3653dc6160354d         10.1093/molbev/msv092
# 1603  66f0539d2d3653dc6160354e             10.3390/v10120715
# 1604  66f056672d3653dc6160354f        10.1038/ismej.2015.125
# 1605  66f05a722d3653dc61603550       10.1073/pnas.1319778111
# 1606  66f05d792d3653dc61603551        10.1093/ismeco/ycae014
#
#                                                   title  \
# 0     eDNA metabarcoding as a biomonitoring tool for...
# 1     MiFish, a set of universal PCR primers for met...
# 2     Detection of a Diverse Marine Fish Fauna Using...
# ...

# %%
test_llm = llm_df.head()
test_llm.to_csv("test_llm.csv", index=False)

# %%
columns_equal = test_llm['DOI'].equals(test_llm['ancestor'])
print(f"Columns are equal: {columns_equal}")
# Out:
# Columns are equal: False
